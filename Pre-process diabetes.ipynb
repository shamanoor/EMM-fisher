# %%
import pandas as pd

# %%
df_diabetes = pd.read_csv('C:/Users/shama/PycharmProjects/thesis/data/diabetes/diabetes_data_upload.csv')

# %%
column_names_old = df_diabetes.columns
column_names_new = df_diabetes.columns.str.replace('\s+', '_')

# %%
df_diabetes.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %%
mapping = {}
for i in range(len(column_names_old)):
    mapping[column_names_old[i]] = column_names_new[i]

# %%
df_diabetes.rename(columns = mapping, inplace=True)

# %%
df_diabetes.columns
# Out:
# Index(['Age', 'Gender', 'Polyuria', 'Polydipsia', 'sudden_weight_loss',
#        'weakness', 'Polyphagia', 'Genital_thrush', 'visual_blurring',
#        'Itching', 'Irritability', 'delayed_healing', 'partial_paresis',
#        'muscle_stiffness', 'Alopecia', 'Obesity', 'class'],
#       dtype='object')

# %% [markdown]
# # Now change all binary variables to True/False

# %%
for column in df_diabetes.columns:
    print(df_diabetes[column].unique())
# Out:
# [40 58 41 45 60 55 57 66 67 70 44 38 35 61 54 43 62 39 48 32 42 52 53 37
#  49 63 30 50 46 36 51 59 65 25 47 28 68 56 31 85 90 72 69 79 34 16 33 64
#  27 29 26]
# ['Male' 'Female']
# ['No' 'Yes']
# ['Yes' 'No']
# ['No' 'Yes']
# ['Yes' 'No']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']
# ['Yes' 'No']
# ['No' 'Yes']
# ['Yes' 'No']
# ['No' 'Yes']
# ['Yes' 'No']
# ['Yes' 'No']
# ['Yes' 'No']
# ['Positive' 'Negative']

# %%
mapping = {"No": False, "Yes": True}

# %%
df_diabetes.replace(mapping, inplace=True)
df_diabetes
# Out:
#      Age  Gender  Polyuria  Polydipsia  sudden_weight_loss  weakness  \
# 0     40    Male     False        True               False      True
# 1     58    Male     False       False               False      True
# 2     41    Male      True       False               False      True
# 3     45    Male     False       False                True      True
# 4     60    Male      True        True                True      True
# ..   ...     ...       ...         ...                 ...       ...
# 515   39  Female      True        True                True     False
# 516   48  Female      True        True                True      True
# 517   58  Female      True        True                True      True
# 518   32  Female     False       False               False      True
# 519   42    Male     False       False               False     False
#
#      Polyphagia  Genital_thrush  visual_blurring  Itching  Irritability  \
# ...

# %%
df_diabetes.rename(columns = {"Gender": "IsFemale"}, inplace=True)

# %%
df_diabetes.replace({"Female": True, "Male": False}, inplace=True)

# %%
df_diabetes
# Out:
#      Age  IsFemale  Polyuria  Polydipsia  sudden_weight_loss  weakness  \
# 0     40     False     False        True               False      True
# 1     58     False     False       False               False      True
# 2     41     False      True       False               False      True
# 3     45     False     False       False                True      True
# 4     60     False      True        True                True      True
# ..   ...       ...       ...         ...                 ...       ...
# 515   39      True      True        True                True     False
# 516   48      True      True        True                True      True
# 517   58      True      True        True                True      True
# 518   32      True     False       False               False      True
# 519   42     False     False       False               False     False
#
#      Polyphagia  Genital_thrush  visual_blurring  Itching  Irritability  \
# ...

# %%
df_diabetes.to_csv("C:/Users/shama/PycharmProjects/thesis/data/diabetes.csv")
